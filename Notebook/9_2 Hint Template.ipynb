# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Oct 30 18:20:09 2018

@author: computer
"""

class Person(object):
    def __init__(self,name = None ,surname = None ,age = None ):
        'เขียน CODE ของนักศึกษาเพิ่มเติม'
        
    def get_name(self):
        return(self.__name)
        
    def set_name(self,newName):
        self.__name = newName
        
    def get_surname(self):
        'เขียน CODE ของนักศึกษาเพิ่มเติม'
        
    def set_surname(self,newsurName):
        'เขียน CODE ของนักศึกษาเพิ่มเติม'
        
    def get_age(self):
        'เขียน CODE ของนักศึกษาเพิ่มเติม'
        
    def set_age(self,newage):
        'เขียน CODE ของนักศึกษาเพิ่มเติม'
        
    def __str__(self):
        return("My name is {}".format(self.get_name()))
    
    
        
class Student(Person):
    countStudent = 1
    def __init__(self,name = None ,surname = None ,age = None ):
        Person.__init__(self,name,surname, age)
        'เขียน CODES ของนักศึกษาเพิ่มเติม'

        
    def __str__(self):
        'เขียน CODE ของนักศึกษาเพิ่มเติม'
    
    def __eq__(self,other):
        'เขียน CODE ของนักศึกษาเพิ่มเติม'
    
    def apply(self,organization):
        # Note organization is an object of StudentOrg 
        
        if  'เติมเงื่อนไข':
            print('{} is already in the organization'.format(self.get_name()))
        else:
            'ทำการ เช็คว่า club จะรับเราหรือไม่โดยการ call eval_apply'
            if organization.eval_apply(self):  
                'ทำการเพิ่ม club ลงใน list ของชมรมที่นักศึกษาเป็นสมาชิกอยู่'
            else:
                print('My application got rejected')
            
            
    
class StudentOrg(object):
    def __init__(self,clubName, founder):
        assert len(founder.organization) == 0, 'Only one club per student'
        'เขียน CODE ของนักศึกษาเพิ่มเติม'
    
         
    
    def add_mem(self,stud):
        'เขียน CODE ของนักศึกษาเพิ่มเติม'

        
    def eval_apply(self, stud):
        # ฟังก์ชั่นเพื่อทำการ ประเมินผู้สมัคร   eval_apply:: Student -> Boolean 
        
        #Note: input: stud is an object from class Student
        
        # ชมรมจะอนุมัติ ให้นักศึกษาที่ถูกส่งเข้ามาเข้า ร่วมชมรมได้ก็ต่อเมื่อนักศึกษายังไม่มีชมรม
        if 'เติมเงื่อนไข':
            return (False)
        else:
            print('Application approved')
            'เติม code เพื่อเพิ่ม stud ลงในสมาชิก club '
            self.add_mem(stud)
            return (True)
        
    def __eq__(self,other):
        return (self.clubName == other.clubName)
    
    def __str__(self):
        msg =''
        
        'เขียน CODE ของนักศึกษาเพิ่มเติม'
        
        return ('We are club {}. Our members are {}'.format( self.clubName, msg))
        
    
    
s1 =Student('s1','sur1',12)
print(s1)
s2 =Student('s2','sur2',13)
print(s2)
s3 =Student('s3','sur3',14)  
print(s3)
c1 = StudentOrg('C1',s1)
print(c1)
c2 = StudentOrg('C2',s2)
print(c2)
c3 = StudentOrg('C3',s3)
print(c3)
s5 =Student('s5','sur5',12)

s6 =Student('s6','sur6',13)

s7 =Student('s7','sur7',14)

#c4 = StudentOrg('c4',s1)

s5.apply(c1)
s1.apply(c1)
s6.apply(c1)
s6.apply(c2)

print(c1.members)

print(c1) 

print(c2.members)

print(c2)
