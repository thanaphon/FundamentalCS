# %% [markdown]
# # ใบงาน
#
#   1) ให้น้อง ๆ ศึกษาการใช้ try and exception handle จาก class lecture note
#
#   2) ทำการ Implement โปรเเกรมดังต่อไปนี้
#
# ให้น้อง ๆ เขียนโปรแกรม เพื่อทำงานดังต่อไปนี้
#
# 1) ทำการรับอินพุทสามตัวจากยูสเซอร์โดยบังคับให้ อินพุท ตัวเเรกเป็น integer และตัวที่สองเป็น float  ตัวที่สามเป็น integer ระหว่าง \[0...10]
# หากยูสเซอร์ คีย์ อินพุทนอกเหนือจากนี้ ให้เราทำการเอาท์พุทข้อความบอกยูสเซอร์ ว่า type ของอินพุท ที่ต้องการคืออะไร
# กำหนดให้ อินพุทเป็น variable x, y ,z ตามลำดับ
#
# 2) ทำการคำนวณ f(w) สำหรับค่า w ตั้งแต่ 0 ถึง z
#   แล้วบันทึกเก็บไว้ใน data dict d[w] = f(w)
#   หาก f(w) ไม่สามารถหาค่าได้ ให้ เก็บเป็นค่าเป็น None และ print warning message เกี่ยวกับปัญหาที่เกิดขึ้น
#
#  f(w) = log(y+w) / (x - w)
#
# Hint: import math  for log function
#
# 3) output ผลลัพท์ของ data dict

# %%
import math
def main():
    
    # Loop for taking input x
    while True: 
        try:
            "ADD your codes here"
            # Read user input and check wherther it's an integer            
            break
        except ValueError:
            "Print out something"
           
    # Loop for taking input y        
    while True: 
        try:
            "ADD your codes here"
            
    #Loop for taking input z    
    while True: 
        try:
            "ADD your codes here"

            
    d = {}
    
    
    for w in range(0,z+1):  
        try:
            "ADD your codes"
         
    
    print(d)

# %% [markdown]
# Example outputs:
#
# main()
#
# please enter an integer number
#
# asd
#
# That doesn't look like an integer number!
#
#
# please enter an integer number
#
# 3
#
# please enter a float number
#
# -1.5
#
# please enter an integer number [0 10]
#
# 12
#
# please enter an integer number [0 10]
#
# wer
#
# That doesn't look like an integer number [0 10]!
#
#
# please enter an integer number [0 10]
#
# 8
#
#  log cannot take nagative value
#
#  log cannot take nagative value
#
#  denominator cannot be 0 value
#
# {0: None, 1: None, 2: -0.6931471805599453, 3: None, 4: -0.9162907318741551, 5: -0.626381484247684, 6: -0.5013591322587581, 7: -0.4261870230596063, 8: -0.37436043538031827}
