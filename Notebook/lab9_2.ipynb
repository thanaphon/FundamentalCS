# %% [markdown]
# วัตถุประสงค์:
#
#     1) เพื่อให้นักศึกษา ฝึกการเขียนโปรแกรมแบบ Object Oriented Programming (OOP) ตามโปรแกรม specification
#
#
#
# ใบงาน:
#
#   1)  ให้นักศึกษารวมกันออกแบบทำการสร้าง class diagrams ซึ่งมี program specification ดังต่อไปนี้
#
# ทางหัวหน้างานของน้อง ๆ  ต้องการให้พัฒนาโปรแกรมเพื่อ ทำการจัดการเก็บข้อมูลทั่วไปของนักศึกษาเเละ ชมรมของนักศึกษา
# โดยที่ทางหัวหน้างาน อาจจะทำการเพิ่มเติมในส่วนของข้อมูลของ บุคคลากร หรืออาจาร์ย เข้ามาในภายหลัง ดังนั้นน้อง ๆ ควรจะออกแบบโปรแกรมเพื่อที่จะไม่ต้องเขียน code ซ้ำ ในส่วนนี้ด้วย  โดยข้อกำหนดพื้นฐานมีดังต่อไปนี้
#
# a) นักศึกษาสามารถ จะต้องมี unique ID เป็นของตัวเอง เเละ นักศึกษาสามารถที่จะสมัครเข้าชมรมต่าง ๆ ได้
#
# b) นักศึกษาสามารถเป็นสมาชิกชมรม ได้เพียงหนึ่งชมรม (เเต่เงื่อนไขนี้อาจจะ เปลี่ยนแปลงได้ภายหลัง)
#
# c) ชมรมสามารถก่อตั้งขึ้นได้ โดยนักศึกษาที่ไม่ได้เป็น สมาชิกของชมรมใด ๆ  โดยกำหนดให้ นักศึกษาผู้ก่อตั้งเป็นประธาน และสมาชิก โดยอัตโนมัติ และ จะรับสมาชิกก็ต่อเมื่อผู้สมัครนั้นไม่ได้เป็น สมาชิกของชมรมใด ๆ
#
#
# ร่วมกันคิดว่า:
#
# a) จากโจทย์ที่กำหนดให้ ควรมี classes พื้นฐานอะไรบ้าง?
#
# b) ความสัมพันธ์ ระหว่างคลาสนั้นเป็นแบบใหน?
#
# c) ในแต่ละคลาส ควรมี attributes อะไรบ้าง
#
#
# 2) ทำการพัฒนา classes ตามที่ได้ออกแบบมาข้างต้น
#
# Hint: )

# %%
class Person(object):
    
    #define your class here

# %% [markdown]
#     1) class Person:
#         1.1) Data attributes ประกอบไปด้วย
#             __name,__surname, __age
#
#         1.2) Method attributes:
#                 1.2.1 สำหรับ constructor __init__ ให้นักศึกษารับ อินพุทมาสามค่า เพื่อทำการ initialize __name, __surname และ __age
#                 โดยกำหนดให้ default values เป็น None
#
#                 1.2.2 get, set functions
#                 get_name(): ทำการ return ค่าของ private attribute __name กลับ
#                 set_name(newName):  ทำการ set ค่าของ private attribute __name  ด้วย newName
#
#                 get_surname(): ทำการ return ค่าของ private attribute __surname กลับ
#                 set_surname(newName):  ทำการ set ค่าของ private attribute __surname  ด้วย newName
#
#                 get_age(): ทำการ return ค่าของ private attribute __age กลับ
#                 set_age(newAge):  ทำการ set ค่าของ private attribute __age  ด้วย newAge
#
#                 1.2.3 สำหรับ constructor __srt__ ให้นักศึกษา return person name กลับออกไป

# %%
class Student(Person):
    
    # define your class here

# %% [markdown]
#   2) class Student:
#
#         2.0 โดยทำการ inherit attributes จาก class Person โดยทำการเพิ่มในส่วนของ
#
#         2.1 class variable
#                     countStudent  ซึ่งกำหนดให้เป็น counter สำหรับ instances ที่ได้ทำการสร้างขึ้นจาก class Student ให้ค่าเริ่มต้นเป็น 1
#
#         2.2 Data attributes ประกอบไปด้วย
#                     _studentID   ซึ่งกำหนดให้เป็น unique ID สำหรับนักศึกษา
#                     organizations ทำการเก็บ list ของ student organizations ที่เป็น สมาชิอยู่
#
#         2.3) Method attributes:
#                 2.3.1 สำหรับ constructor __init__ ให้นักศึกษาเรียกใช้ init constuctor จาก class Person
#                 กำหนดให้  self.organizations เริ่มต้นเป็น emply list
#                 กำหนดค่า  self.studentID = countStudent  และ ทำการเพิ่ม ค่า class variable countStudent
#
#                 2.3.2 ทำการ override function __str__ ให้ทำการ return string ชื่อ และ ID ของนักศึกษา กลับออกไป
#                 Ex.   "Myname is {}. My ID is {}".format( self.get_name(), self._studentID )
#
#                 2.3.3 ทำการ override function __eq__(self, other)
#                 ให้ return True ถ้า studentID ของ  self และ other นั้นเหมือนกัน  False ถ้า ไม่เหมือน
#
#                 2.3.4 ทำการ implement apply(self, organization)
#                     -ให้ทำการเรียก organization.eval_apply(self)   เปรียบได้กับการส่งใบสมัคร
#
#                     ถ้าใบสมัครผ่าน
#
#                             - ให้ทำการ add organization ที่พาสเข้ามาลงใน list ของ self.organizations
#
#
#                     ถ้าไม่ผ่าน
#                             - ให้ print ('Application got rejected')

# %%
class StudentOrg(object):
    
    # define your class here

# %% [markdown]
#   3) ให้นักศึกษาสร้าง class StudentOrg: กำหนดให้นักศึกษาหนึ่งคนเป็นสมาชิกได้เพียง 1 club
#
#
#          3.1) Data attributes ประกอบไปด้วย
#             clubName  เก็บชื่อของชมรม
#             president เก็บนักศึกษาประธานชมรม
#             members ทำหน้าที่เก็บลิสของ สมาชิกในชมรม
#
#          3.2) Method attributes:
#                 3.3.1 สำหรับ constructor __init__  รับอินพุทสองตัว ตัวเเรกเป็น instance ของ student  ตัวที่สองเป็นชื่อชมรม
#                     ถ้า instance ของ student ที่ถูก pass เข้ามามี club อยู่แล้ว ให้ยกเลิกการสร้าง club โดยการใช้ assert และ precondition
#
#                 ถ้ายังไม่มี club
#                     กำหนดให้  self.president เป็น นักเรียนที่ถูก pass เข้ามา
#                     กำหนดให้  self.members เริ่มต้นเป็นลิส ที่มี self.president เป็นสมาชิก
#                     ทำการเพิ่ม  self ลงใน organization ของ instance student ที่ส่งเข้ามา
#                     กำหนดค่า  self.clubName เป็นชื่อชมรมที่ถูกส่งเข้ามา
#
#
#                 3.3.2 ทำการสร้าง eval_apply(self, stud):
#                     return False ถ้าเป็น สมาชิกอยู่เเล้ว หรือเป็นสมาชิกของคลับอื่นอยู่แล้ว
#                     นอกนั้น ทำการ เรียก add_mem(self,stud) เเละ
#                     return True
#
#
#                 3.3.2 ทำการสร้าง add_mem(self,stud):
#                 - ทำการ add stud ลงใน club members
#                 เช็คด้วยว่าถ้าเป็น สมาชิกอยู่เเล้ว ไม่ต้อง add student เดิมเข้ามา
#
#                 3.3.3 ทำการ override function __str__ ให้ทำการ return string ชื่อของสมาชิกในกลุ่มกลับออกไป

# %%
#ทดลองทำการสร้าง instances ของ class Student และ StudentOrg 
#Example:

s1 =Student('s1','sur1',12)
s2 =Student('s2','sur2',13)
s3 =Student('s3','sur3',14)  
 
c1 = StudentOrg('C1',s1)
c2 = StudentOrg('C2',s2)
c3 = StudentOrg('C3',s3)
#c4 = StudentOrg('C4',s1)  #Should assert error

s5 =Student('s5','sur5',12)
s6 =Student('s6','sur6',13)
s7 =Student('s7','sur7',14)


s5.apply(c1)
s1.apply(c1)  # should handle this case 
s6.apply(c1)  
s6.apply(c2)  # should handle this case 

print(c1.members)
print(c1) 
print(c2.members)
print(c2)
